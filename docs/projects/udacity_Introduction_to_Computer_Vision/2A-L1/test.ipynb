# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import cv2
from  matplotlib import pyplot as plt

# %% [markdown]
# # Hello

# %%
image = cv2.imread("images/dolphin.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# row / y, col/ x
image.shape
image.size
# pixel data type 0-255 / uint8
image.dtype

image[100:103,200:203]

_ = plt.imshow(image, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# (320, 500)
# 160000
# dtype('uint8')
# array([[81, 77, 77],
#        [81, 78, 76],
#        [82, 79, 77]], dtype=uint8)

# %%
_ = plt.hist(image.ravel(),256,[0,256])
plt.show()
